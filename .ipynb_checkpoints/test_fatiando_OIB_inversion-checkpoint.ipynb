# %%
import numpy as np
import matplotlib.pyplot as plt
from my_OIB_functions import *
import fatiando
import pandas as pd
# %matplotlib inline

# %%
def oib_lineplot_cust(data, ptitle='test_lineplot', pname='test_lineplot'):
    import matplotlib.pyplot as plt
    data.loc[data['HYDROAPPX'] < -1500, 'HYDROAPPX'] = np.nan
    fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 8))
    data['FAG070'].where((data['FLTENVIRO'] == 1)).plot(ax=axes[0], legend=True, label='Disturbed', style='r-')
    data['FAG070'].where((data['FLTENVIRO'] == 0)).plot(ax=axes[0], legend=True, label='Normal', style='k-')
    # data['FAG070'].where((data['FLTENVIRO'] == -1)).plot(ax=axes[0], legend=True, label='Missing', style='b-')
#     data['ELEVATION'].plot(ax=axes[1], legend=True, style='y.')
    data['ICEBASE'].plot(ax=axes[1], legend=True, marker=".", linestyle="None", color="brown")
    data['TOPOGRAPHY_radar'].plot(ax=axes[1], legend=True, marker=".", linestyle="None", color="blue")
#     data['HYDROAPPX'].plot(ax=axes[1], legend=True, color='grey')
    data['SURFACE_atm'].where((data['NUMUSED'] > 77)).plot(ax=axes[1], legend=True, 
                                                           marker=".", linestyle="None", color='cyan')
    plt.suptitle(ptitle, y=0.98)
#     plt.savefig(pname, bbox_inches='tight')   # save the figure to file
#     plt.close(fig)
    return

# %%
df = pd.read_csv('data/agg2invert/OIB_ANT_2010-05-19.csv')
oib_lineplot_cust(df)

# %%
segment = 1274277755
# plt.plot(df['LINE'].where((df['LINE'] == segment)))
# oib_lineplot_cust(df.where((df['LINE'] == segment)))

# %%
gb = df.groupby(['LINE'])

# %%
# gb.describe()

# gb['FAG070'].describe()

# Group the dataframe by regiment, and for each regiment,
for name, group in gb:
    # print the name of the regiment
    print(name)
    # print the data of that regiment
    print(group['FAG070'].describe())
# Out:
# 1274263911
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: FAG070, dtype: float64
# 1274267105
# count    487.000000
# mean      57.320329
# std       17.886941
# min       31.140000
# 25%       37.385000
# 50%       60.430000
# 75%       74.285000
# max       81.050000
# Name: FAG070, dtype: float64
# 1274267348
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: FAG070, dtype: float64
# 1274267810
# count    1938.000000
# mean       65.698400
# std        12.483432
# min        44.020000
# 25%        54.975000
# 50%        66.820000
# 75%        77.900000
# max        85.990000
# Name: FAG070, dtype: float64
# 1274268779
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: FAG070, dtype: float64
# 1274268992
# count    1320.000000
# mean       34.028144
# std        17.235079
# min        -1.030000
# 25%        20.820000
# 50%        43.080000
# 75%        49.250000
# max        55.220000
# Name: FAG070, dtype: float64
# 1274269652
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: FAG070, dtype: float64
# 1274269801
# count    502.000000
# mean     -19.714482
# std        7.400625
# min      -32.080000
# 25%      -25.087500
# 50%      -20.100000
# 75%      -14.647500
# max       -5.560000
# Name: FAG070, dtype: float64
# 1274270052
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: FAG070, dtype: float64
# 1274270220
# count    2244.000000
# mean       13.732870
# std        10.849082
# min        -7.470000
# 25%         5.947500
# 50%        10.940000
# 75%        23.500000
# max        31.600000
# Name: FAG070, dtype: float64
# 1274271342
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: FAG070, dtype: float64
# 1274271798
# count    2400.000000
# mean       17.914842
# std        25.764158
# min       -45.400000
# 25%        -2.630000
# 50%        28.445000
# 75%        38.262500
# max        50.600000
# Name: FAG070, dtype: float64
# 1274272998
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: FAG070, dtype: float64
# 1274273116
# count    595.000000
# mean     -16.848118
# std        8.232509
# min      -42.190000
# 25%      -21.610000
# 50%      -15.670000
# 75%      -11.105000
# max       -4.740000
# Name: FAG070, dtype: float64
# 1274273413
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: FAG070, dtype: float64
# 1274273930
# count    1998.000000
# mean       15.215836
# std        17.154699
# min       -22.960000
# 25%         5.022500
# 50%        18.965000
# 75%        25.460000
# max        44.380000
# Name: FAG070, dtype: float64
# 1274274929
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: FAG070, dtype: float64
# 1274275202
# /usr/local/lib/python2.7/site-packages/numpy/lib/function_base.py:4116: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
# count    2052.000000
# mean       10.489264
# std        16.919004
# min       -22.580000
# 25%        -3.722500
# 50%         6.635000
# 75%        21.885000
# max        40.790000
# Name: FAG070, dtype: float64
# 1274276228
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: FAG070, dtype: float64
# 1274276308
# count    382.000000
# mean     -38.749607
# std        4.154842
# min      -45.720000
# 25%      -42.307500
# 50%      -38.615000
# 75%      -34.935000
# max      -33.060000
# Name: FAG070, dtype: float64
# 1274276499
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: FAG070, dtype: float64
# 1274277474
# count    379.000000
# mean      27.245251
# std        9.023624
# min       12.460000
# 25%       18.110000
# 50%       31.560000
# 75%       35.170000
# max       36.950000
# Name: FAG070, dtype: float64
# 1274277664
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: FAG070, dtype: float64
# 1274277755
# count    1938.000000
# mean      -36.386228
# std        60.410525
# min       -99.170000
# 25%       -91.257500
# 50%       -69.550000
# 75%        28.860000
# max        60.230000
# Name: FAG070, dtype: float64
# 1274278724
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: FAG070, dtype: float64
# 1274278921
# count    1727.000000
# mean      -46.646989
# std        38.157407
# min       -91.870000
# 25%       -79.680000
# 50%       -54.890000
# 75%       -30.385000
# max        67.750000
# Name: FAG070, dtype: float64
# 1274279784
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: FAG070, dtype: float64
# 1274281690
# count    509.000000
# mean     -45.176287
# std       16.320206
# min      -69.410000
# 25%      -59.190000
# 50%      -47.590000
# 75%      -32.940000
# max      -12.670000
# Name: FAG070, dtype: float64
# 1274281944
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: FAG070, dtype: float64
# 1274283651
# count    369.000000
# mean     -28.208130
# std       14.062914
# min      -49.160000
# 25%      -41.590000
# 50%      -28.480000
# 75%      -16.580000
# max       -5.420000
# Name: FAG070, dtype: float64
# 1274283835
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: FAG070, dtype: float64
# 1274285981
# count    495.000000
# mean     -15.063818
# std       14.247070
# min      -37.080000
# 25%      -28.245000
# 50%      -12.990000
# 75%       -4.980000
# max       11.760000
# Name: FAG070, dtype: float64
# 1274286229
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: FAG070, dtype: float64
# 1274286350
# count    420.000000
# mean     -15.108738
# std       17.772300
# min      -40.530000
# 25%      -31.450000
# 50%      -16.155000
# 75%        2.247500
# max       13.400000
# Name: FAG070, dtype: float64
# 1274286560
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: FAG070, dtype: float64
# 1274288341
# count    428.000000
# mean       9.883248
# std       18.057274
# min      -20.480000
# 25%       -6.645000
# 50%       11.495000
# 75%       30.140000
# max       32.680000
# Name: FAG070, dtype: float64
# 1274288555
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: FAG070, dtype: float64
# 1274290692
# count    407.000000
# mean       5.271425
# std        2.263118
# min        2.730000
# 25%        3.285000
# 50%        4.680000
# 75%        6.925000
# max       10.500000
# Name: FAG070, dtype: float64
# 1274290895
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: FAG070, dtype: float64

# %%
# gb[["TIME", "FAG070"]].get_group(segment)
lf = gb.get_group(segment)
oib_lineplot_cust(lf)
# Out:
# /usr/local/lib/python2.7/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
lf.head()
# Out:
#                          iunix        LAT       LONG        DATE  DOY  \
# 27689  2010-05-19 14:02:35.500  72.658552 -51.769381  2010-05-19  139
# 27690  2010-05-19 14:02:36.000  72.657918 -51.768901  2010-05-19  139
# 27691  2010-05-19 14:02:36.500  72.657284 -51.768429  2010-05-19  139
# 27692  2010-05-19 14:02:37.000  72.656650 -51.767963  2010-05-19  139
# 27693  2010-05-19 14:02:37.500  72.656015 -51.767505  2010-05-19  139
#
#           TIME  FLT        PSX         PSY   WGSHGT    ...      SURFACE_radar  \
# 27689  50555.5   26 -223068.90 -1879253.25  2210.22    ...             434.57
# 27690  50556.0   26 -223061.42 -1879324.81  2211.29    ...             434.58
# 27691  50556.5   26 -223054.20 -1879396.37  2212.35    ...             434.60
# 27692  50557.0   26 -223047.21 -1879467.94  2213.39    ...             434.61
# 27693  50557.5   26 -223040.48 -1879539.52  2214.40    ...             434.61
#
#         BOTTOM  QUALITY  SURFACE_atm  NUMUSED   ICEBASE  TOPOGRAPHY_radar  \
# 27689  1949.80      1.0    1790.8337    608.0  262.0974         1777.3274
# 27690  1937.49      1.0    1791.2783    603.0  275.5374         1778.4474
# 27691  1925.17      1.0    1791.7584    603.0  288.9532         1779.5232
# 27692  1913.97      1.0    1801.5708    616.0  301.1545         1780.5145
# 27693  1907.22      1.0    1801.5708    616.0  308.8415         1781.4515
#
#        D_gravmask        LINE  HYDROAPPX
# 27689           1  1274277755        NaN
# 27690           1  1274277755        NaN
# 27691           1  1274277755        NaN
# 27692           1  1274277755        NaN
# 27693           1  1274277755        NaN
#
# [5 rows x 34 columns]

# %%
lf['BED_flat'] = -(lf['SURFACE_atm'] - lf['ICEBASE'])

lf['BED_flat'].plot()
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %% [markdown]
# # Fatiando testing
# Estimate the relief of a sedimentary basin approximating by a polygon.
#
# Currently only works with gravity data.
#
# The top of the basin is straight and fixed at a given height. Polygon vertices are distributed evenly in the x-direction. The inversion estimates the depths of each vertex.
#
# This is a non-linear inversion. Therefore you must configure it before running to choose a solver method and set the initial estimate. Use the config method for this.
#
# Recommended configuration: Levemberg-Marquardt algorithm ('levmarq') with initial estimate to the average expected depth of the basin.
#
# Typical regularization to use with this class are: Damping, Smoothness1D, TotalVariation1D.
#
# The forward modeling is done using talwani. Derivatives are calculated using a 2-point finite difference approximation.
#
# Tip
# Use the estimate_ attribute to get a Polygon version of the estimated parameters (attribute p_).

# %%
from fatiando.inversion import Smoothness1D
from fatiando.gravmag.basin2d import PolygonalBasinGravity
from fatiando.gravmag import talwani
from fatiando.mesher import Polygon
from fatiando.vis import mpl
from fatiando import utils
import numpy as np
# Out:
# /usr/local/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")

# %%
# Make some synthetic data to test the inversion
# The model will be a polygon.
# Reverse x because vertices must be clockwise.
xs = np.linspace(0, 100000, 100)[::-1]
depths = (-1e-15*(xs - 50000)**4 + 8000 -
          3000*np.exp(-(xs - 70000)**2/(10000**2)))
# depths[50:85] -= 2000  # DFP testing the synthetic data
depths -= depths.min()  # Reduce depths to zero

depths_oib = np.array(depths)
depths_oib[1:30] = depths_oib[30]

plt.plot(depths)
plt.plot(depths_oib)

# %% [markdown]
# # Make a polygon from the synthetic data

# %%
props = {'density': -300}
model = Polygon(np.transpose([xs, depths]), props)
model_oib = Polygon(np.transpose([xs, depths_oib]), props)

# %% [markdown]
# # Forward Model to get FAG

# %%
x = np.linspace(0, 100000, 100)
z = -100*np.ones_like(x)
data = utils.contaminate(talwani.gz(x, z, [model]), 0.5, seed=0)
data_oib = utils.contaminate(talwani.gz(x, z, [model_oib]), 0.5, seed=0)

# data[85:-1] = np.diff(data[85:-1].values)# - (data[85:-1] - data[84:-2])
plt.plot(data)
plt.plot(data_oib)

# %% [markdown]
# # Construct a solver
# Each class represents a regularizing function. They can be used by adding them to a Misfit derivative (all inversions in Fatiando are derived from Misfit). The regularization parameter is set by multiplying the regularization instance by a scalar, e.g., solver = misfit + 0.1*regularization.

# %%
# Make the solver using smoothness regularization and run the inversion
misfit = PolygonalBasinGravity(x, z, data, 50, props, top=0)
regul = Smoothness1D(misfit.nparams)
solver = misfit + 1e-4*regul


# This is a non-linear problem so we need to pick an initial estimate
initial = 3000*np.ones(misfit.nparams)
solver.config('levmarq', initial=initial).fit()
# Out:
# /usr/local/lib/python2.7/site-packages/fatiando/inversion/optimization.py:302: RuntimeWarning: Exited because maximum iterations reached. Might not have achieved convergence. Try inscreasing the maximum number of iterations allowed.
#   RuntimeWarning)

# %% [markdown]
# # Solve
# This is a non-linear problem so we need to pick an initial estimate

# %%
initial = 3000*np.ones(misfit.nparams)
solver.config('levmarq', initial=initial).fit()

# %%
mpl.figure()
mpl.subplot(2, 1, 1)
mpl.plot(x, data, 'ok', label='Gravity Data')
# mpl.plot(x, solver[0].predicted(), '-r', linewidth=2, label='predicted Gravity')
mpl.legend()
ax = mpl.subplot(2, 1, 2)
mpl.polygon(model_oib, fill='gray', alpha=0.5, label='Guess')
# The estimate_ property of our solver gives us the estimate basin as a polygon
# So we can directly pass it to plotting and forward modeling functions
mpl.plot(x[:70], depths[:29:-1], color='black', linewidth=10, label='Constraints')
mpl.polygon(solver.estimate_, style='.-k', label='Inverted')
ax.invert_yaxis()
mpl.legend()
mpl.show()

# %% [markdown]
# "The estimated parameter vector is stored in the p_ attribute. Misfit also provides a estimate_ attribute that can be a custom (user defined) formatted version of p_. It’s better to use estimate_ if you’re not interested in the parameter vector as it is. Since we didn’t implement this custom formatting, both should give the same value."

# %%
print solver.p_
# print solver.estimate_
print solver[0].predicted()
# Out:
# [  887.56388257  1723.70692572  2404.44998154  3072.28133737  3639.40665098
#   4001.10788418  4208.39358354  4372.47493185  4473.19386127  4443.02728833
#   4250.68510761  3902.84061508  3461.00574575  3078.53310283  2958.39623842
#   3157.83705156  3561.10635315  4058.43930827  4559.12696803  4994.6841701
#   5351.91752122  5650.05158527  5903.37980918  6100.57119249  6226.75048791
#   6285.20957156  6295.82915774  6288.09905024  6282.48253587  6272.82657923
#   6247.92858966  6228.18396851  6229.09680231  6210.43790283  6124.67467201
#   5994.66432759  5883.79210347  5815.22415773  5767.23405471  5696.7304254
#   5532.92474064  5226.83202141  4820.33782625  4398.49816523  4002.39156216
#   3622.55857787  3168.84391046  2505.54943864  1632.81759626   855.26254836]
# [ -8.37210033 -13.91691753 -18.85706421 -23.32092516 -27.46422781
#  -31.30236272 -34.79622394 -37.94320738 -40.78128889 -43.36188093
#  -45.7362428  -47.94797254 -50.0287876  -51.99771679 -53.86250388
#  -55.6224624  -57.27189816 -58.80348203 -60.21114552 -61.49218821
#  -62.64840696 -63.68622659 -64.61598476 -65.45063345 -66.20416442
#  -66.89004319 -67.51987555 -68.10246393 -68.64335614 -69.14493856
#  -69.60705097 -70.02799105 -70.40566922 -70.73862099 -71.02662531
#  -71.27080778 -71.47327669 -71.63648313 -71.76255551 -71.85281562
#  -71.90756286 -71.92607939 -71.90672924 -71.84702942 -71.74364063
#  -71.59230993 -71.38784692 -71.12421133 -70.7947457  -70.39253203
#  -69.91081146 -69.34339145 -68.68497168 -67.93133971 -67.07941448
#  -66.12715149 -65.0733696  -63.91760946 -62.66017495 -61.30252091
#  -59.84812309 -58.30390512 -56.68221043 -55.00320266 -53.29742967
#  -51.60813502 -49.99269815 -48.52206638 -47.27651    -46.33504701
#  -45.75813136 -45.56698934 -45.73097547 -46.17451275 -46.79687636
#  -47.49573329 -48.18293909 -48.79032803 -49.26942708 -49.58830939
#  -49.72791185 -49.67866696 -49.43750577 -49.00495156 -48.38203733
#  -47.56712225 -46.55319679 -45.32663196 -43.86829935 -42.15698704
#  -40.17405043 -37.90764199 -35.35409986 -32.51510289 -29.38628769
#  -25.93456584 -22.0905799  -17.78454162 -12.90452289  -7.3368726 ]

# %% [markdown]
# # Back to Greenland

# %%
bottom = -np.array(lf['BED_flat'])
fag070 = -np.array(lf['FAG070'])
xs = np.linspace(0, 100000, len(bottom))[::-1]
x = np.linspace(0, 100000, len(bottom))
z = -100*np.ones_like(x)

# Make a "water" block
bottom[1085:] = bottom[1085]
# depths = [0,[bottom],0]
bottom[0] = 0 
bottom[len(bottom)-1] = 0
plt.plot(bottom)

# %%
bottom -= bottom.min()  # Reduce depths to zero
plt.plot(bottom)

# %%
props = {'density': -1700}
model_real = Polygon(np.transpose([xs, bottom]), props)

# %%
# Make the solver using smoothness regularization and run the inversion
misfit = PolygonalBasinGravity(x, z, fag070, 50, props, top=0)
regul = Smoothness1D(misfit.nparams)
solver = misfit + 1e-4*regul

# %%
# This is a non-linear problem so we need to pick an initial estimate
initial = 300*np.ones(misfit.nparams)
solver.config('levmarq', initial=initial).fit()

# %%
mpl.figure()
mpl.subplot(2, 1, 1)
mpl.plot(x, fag070, 'ok', label='Gravity Data')
# mpl.plot(x, solver[0].predicted(), '-r', linewidth=2, label='predicted Gravity')
mpl.legend()
ax = mpl.subplot(2, 1, 2)
mpl.polygon(model_real, fill='gray', alpha=0.5, label='Guess')
# The estimate_ property of our solver gives us the estimate basin as a polygon
# So we can directly pass it to plotting and forward modeling functions
# mpl.plot(x[:70], bottom[:29:-1], color='black', linewidth=10, label='Constraints')
mpl.polygon(solver.estimate_, style='.-r', label='Inverted')
ax.invert_yaxis()
mpl.legend()
mpl.show()

# %% [markdown]
# # DEBUGGING

# %%
model_real.vertices
# Out:
# array([[  0.00000000e+00,   0.00000000e+00],
#        [  5.16262261e+01,   1.51574090e+03],
#        [  1.03252452e+02,   1.50280520e+03],
#        ...,
#        [  9.98967475e+04,   3.21745800e+02],
#        [  9.99483738e+04,   3.21745800e+02],
#        [  1.00000000e+05,   0.00000000e+00]])

# %%
bottom = np.array(lf['BED_flat'])
# bottom = lf['BED_flat']
print bottom
# print lf['BED_flat'][28767]
# lf['BED_flat'][28767:b]
# lf['BED_flat'][0:]
# Out:
# [-1528.7363 -1515.7409 -1502.8052 ...,    -8.7095    -9.3118    -9.9288]
